# %%
from gcpds.utils.loaddb import databases
from gcpds.utils.mne_handler import get_best_montage

# %%
get_best_montage(databases.giga['channels'])
# Out:
#     count  missings                                  missings channels  \
# 0      64         0                                                 {}
# 1      64         0                                                 {}
# 2      64         0                                                 {}
# 3      64         0                                                 {}
# 4      32        32  {C6, F2, AF8, P5, C1, FT7, FC3, TP7, AF7, TP8,...
# 5      30        34  {AF3, PO4, AF8, PO3, FT7, FC3, TP7, TP8, P7, T...
# 6      30        34  {AF3, PO4, AF8, PO3, FT7, FC3, TP7, TP8, P7, T...
# 7      30        34  {AF3, PO4, AF8, PO3, FT7, FC3, TP7, TP8, P7, T...
# 8      29        35  {AF3, PO4, AF8, PO3, FT7, FC3, TP7, TP8, P7, T...
# 9      16        48  {AF3, C6, F2, PO4, AF8, P5, C1, PO3, FT7, FC3,...
# 10     14        50  {Fp1, AF3, O1, PO4, AF8, Fz, P5, Fp2, PO3, FT7...
# 11      6        58  {Fp1, AF3, O1, F2, PO4, AF8, Fz, P5, Fp2, PO3,...
# ...

# %%
get_best_montage(databases.bci2a['channels'])
# Out:
#     count  missings                                  missings channels  \
# 0      22         0                                                 {}
# 1      22         0                                                 {}
# 2      22         0                                                 {}
# 3      22         0                                                 {}
# 4      11        11  {POz, CP4, FC4, CP2, FC2, FC1, CPz, FC3, CP3, ...
# 5      11        11  {POz, CP4, FC4, CP2, FC2, FC1, CPz, FC3, CP3, ...
# 6      11        11  {POz, CP4, FC4, CP2, FC2, FC1, CPz, FC3, CP3, ...
# 7      11        11  {POz, CP4, FC4, CP2, FC2, FC1, CPz, FC3, CP3, ...
# 8       9        13  {P2, C6, POz, C5, CP4, C1, P1, FC4, CPz, FC3, ...
# 9       6        16  {Pz, P2, POz, Fz, CP4, P1, FC4, CP2, FC2, FC1,...
# 10      6        16  {Pz, P2, POz, Fz, CP4, P1, FC4, CP2, FC2, FC1,...
# 11      6        16  {Pz, P2, POz, Fz, CP4, P1, FC4, CP2, FC2, FC1,...
# ...

# %%
get_best_montage(databases.highgamma['channels'])
# Out:
#     count  missings                                  missings channels  \
# 0     128         5               {EMG_RH, EMG_RF, EOGv, EMG_LH, EOGh}
# 1      72        61  {CPP2h, FFT7h, I2, CCP5h, TPP9h, FTT10h, AFF5h...
# 2      68        65  {CPP2h, FFT7h, I2, CCP5h, TPP9h, FTT10h, AFF5h...
# 3      64        69  {CPP2h, FFT7h, PO10, I2, CCP5h, TPP9h, FTT10h,...
# 4      32       101  {C6, I2, TPP9h, AFF5h, FFC4h, TP8, FC4, FFC3h,...
# 5      32       101  {I2, TPP9h, AFF5h, FFC4h, TP8, P7, FC4, FFC3h,...
# 6      32       101  {I2, TPP9h, AFF5h, FFC4h, TP8, P7, FC4, FFC3h,...
# 7      32       101  {I2, TPP9h, AFF5h, FFC4h, TP8, P7, FC4, FFC3h,...
# 8      31       102  {I2, TPP9h, AFF5h, FFC4h, TP8, P7, FC4, FFC3h,...
# 9      16       117  {C6, I2, TPP9h, AFF5h, FFC4h, TP8, P7, FC4, FF...
# 10     14       119  {I2, TPP9h, Fz, AFF5h, FFC4h, TP8, P7, FC4, FF...
# 11      6       127  {I2, TPP9h, Fz, AFF5h, FFC4h, TP8, P7, FC4, FF...
# ...
